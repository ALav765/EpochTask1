# %%
import tensorflow as tf
import librosa
import librosa.display
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import os
import torchaudio
import torch.nn.functional as F
import kagglehub
import cv2
from transformers import AutoTokenizer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Dropout, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, Dropout, Bidirectional

# %%
# Preprocessing for CNN

path = kagglehub.dataset_download("uwrfkaggler/ravdess-emotional-speech-audio")

wav = []
for root, dirs, files in os.walk(path):
    for file in files:
        if file.endswith(".wav"):
            wav.append(os.path.join(root, file))

path = wav[0]

audio, sr = librosa.load(path, sr=16000) # using 16k because its the standard for nlp
print(f"Sample rate after Resampling: {sr}")

target_length = 3 * 16000

def padding(audio, target_length):
    if len(audio) > target_length:
        audio = audio[:target_length]
    else:
        audio = F.pad(audio, (0, target_length - len(audio)))
    return audio

padding(audio, target_length)

def logmel_spectrogram(y, sr, n_mels=128, hop_length=512):
    mel_spectrogram = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=n_mels, hop_length=hop_length)
    logmel_spectrogram = librosa.power_to_db(mel_spectrogram, ref=np.max)
    logmel_spectrogram = cv2.resize(
        logmel_spectrogram,
        (128, 128)
    )
    return logmel_spectrogram

ls = logmel_spectrogram(audio, sr=16000)

plt.figure(figsize=(8, 4))
librosa.display.specshow(ls, sr=sr, hop_length=512, x_axis='time', y_axis='mel')
plt.colorbar(format='%+2.0f dB')
plt.title('Log-Mel Spectrogram')
plt.show()
# Out:
# Using Colab cache for faster access to the 'ravdess-emotional-speech-audio' dataset.
# Sample rate after Resampling: 16000

# %%
print(wav)
# Out:
# ['/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-08-01-01-01-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-01-01-01-01-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-07-02-01-02-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-07-01-01-02-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-01-01-02-01-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-06-02-02-01-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-04-01-02-01-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-01-01-01-02-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-02-01-01-02-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-03-01-01-01-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-07-01-02-02-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-05-01-01-02-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-03-01-01-02-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-06-02-01-02-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-08-02-02-01-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-06-02-01-01-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-06-01-02-02-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-02-01-02-01-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-04-02-02-02-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-03-02-01-02-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-07-01-01-01-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-08-02-01-01-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-05-02-01-01-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-03-02-02-01-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-06-01-01-01-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-05-01-02-02-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-05-02-02-01-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-05-02-02-02-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-08-02-01-02-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-02-01-02-02-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-08-02-02-02-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-03-02-02-02-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-02-02-02-01-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-05-01-01-01-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-05-02-01-02-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-03-02-01-01-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-04-02-01-02-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-07-02-02-02-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-04-02-02-01-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-02-02-02-02-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-06-01-02-01-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-02-02-01-02-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-08-01-02-01-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-07-01-02-01-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-02-01-01-01-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-06-02-02-02-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-03-01-02-02-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-06-01-01-02-02.wav', '/kaggle/input/ravdess-emotional-speech-audio/Actor_02/03-01-05 ...

# %%
# !pip install openai-whisper
import whisper
# Out:
# Collecting openai-whisper
#   Downloading openai_whisper-20250625.tar.gz (803 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.2/803.2 kB 18.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from openai-whisper) (10.8.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from openai-whisper) (0.60.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from openai-whisper) (2.0.2)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.12/dist-packages (from openai-whisper) (0.12.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from openai-whisper) (2.10.0+cu128)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from openai-whisper) (4.67.3)
# Requirement already satisfied: triton>=2 in /usr/local/lib/python3.12/dist-packages (from openai-whisper) (3.6.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba->openai-whisper) (0.43.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken->openai-whisper) (2025.11.3)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from tiktoken->openai-whisper) (2.32.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (1.13.1.3)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch->openai-whisper) (1.5.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2026.4.22)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->openai-whisper) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->openai-whisper) (3.0.3)
# Building wheels for collected packages: openai-whisper
#   Building wheel for openai-whisper (pyproject.toml) ... done
#   Created wheel for openai-whisper: filename=openai_whisper-20250625-py3-none-any.whl size=803979 sha256=c4af2e292fe34b83811e5e7d6a42280e0ffeb138964c3ebda91a851a2c523ac2
#   Stored in directory: /root/.cache/pip/wheels/61/d2/20/09ec9bef734d126cba375b15898010b6cc28578d8afdde5869
# Successfully built openai-whisper
# Installing collected packages: openai-whisper
# Successfully installed openai-whisper-20250625

# %%
'''
model = whisper.load_model("base")

transcriptions = []
for audio_path in wav[:500]: # started with 10 to test
    result = model.transcribe(audio_path)
    transcriptions.append({
        "file": os.path.basename(audio_path),
        "text": result["text"].strip()
    })

with open("transcript.txt", "w", encoding="utf-8") as f:
    for item in transcriptions:
        f.write(f"{item['file']}: {item['text']}\n")
'''
# Out:
# '\nmodel = whisper.load_model("base")\n\ntranscriptions = []\nfor audio_path in wav[:500]: # started with 10 to test\n    result = model.transcribe(audio_path)\n    transcriptions.append({\n        "file": os.path.basename(audio_path),\n        "text": result["text"].strip()\n    })\n\nwith open("transcript.txt", "w", encoding="utf-8") as f:\n    for item in transcriptions:\n        f.write(f"{item[\'file\']}: {item[\'text\']}\n")\n'

# %%
'''
# !pip install transformers

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
with open("transcript.txt", "r", encoding="utf-8") as f:
    lines = f.readlines()

texts = [line.split(":", 1)[1].strip() for line in lines if ":" in line]
tokenized = tokenizer(
    texts,
    padding='max_length', # pad to longest in batch
    truncation=True, # truncate if over max_length
    max_length=128,
    return_tensors="pt"  # return PyTorch tensors
)
'''
# Out:
# '\n!pip install transformers\n\ntokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")\nwith open("transcript.txt", "r", encoding="utf-8") as f:\n    lines = f.readlines()\n\ntexts = [line.split(":", 1)[1].strip() for line in lines if ":" in line]\ntokenized = tokenizer(\n    texts,\n    padding=\'max_length\', # pad to longest in batch\n    truncation=True, # truncate if over max_length\n    max_length=128,\n    return_tensors="pt"  # return PyTorch tensors\n)\n'

# %%
#HARDCODE
def get_transcript(filepath):
    filename = os.path.basename(filepath)
    statement = filename.split("-")[4]   # 5th field

    if statement == "01":
        return "kids are talking by the door"
    else:
        return "dogs are sitting by the door"

transcripts = [get_transcript(f) for f in wav]

# %%
import torch
#mapping emotions and loading using librosa

emotions=[]

#Emotion (01 = neutral, 02 = calm, 03 = happy, 04 = sad, 05 = angry, 06 = fear, 07 = disgust, 08 = surprised)
for file in wav:
    if file.split('-')[5] == '01':
        emotions.append("neutral")
    elif file.split('-')[5] == '02':
        emotions.append("calm")
    elif file.split('-')[5] == '03':
        emotions.append("happy")
    elif file.split('-')[5] == '04':
        emotions.append("sad")
    elif file.split('-')[5] == '05':
        emotions.append("angry")
    elif file.split('-')[5] == '06':
        emotions.append("fear")
    elif file.split('-')[5] == '07':
        emotions.append("disgust")
    elif file.split('-')[5] == '08':
        emotions.append("surprised")

print(emotions)

fts = []

for file in wav:
    x, sr = librosa.load(file,duration=3,sr=16000,offset=0.5)
    x = torch.from_numpy(x)
    x = padding(x, target_length)
    mel = logmel_spectrogram(x.numpy(), sr=16000)
    fts.append(mel)

X = np.array(fts)
X = (X-X.min())/(X.max()-X.min())
X = (X - X.mean(axis=(1,2), keepdims=True))/(X.std(axis=(1,2), keepdims=True) + 1e-8)
X = np.expand_dims(X, axis=-1)
# Out:
# ['surprised', 'neutral', 'disgust', 'disgust', 'neutral', 'fear', 'sad', 'neutral', 'calm', 'happy', 'disgust', 'angry', 'happy', 'fear', 'surprised', 'fear', 'fear', 'calm', 'sad', 'happy', 'disgust', 'surprised', 'angry', 'happy', 'fear', 'angry', 'angry', 'angry', 'surprised', 'calm', 'surprised', 'happy', 'calm', 'angry', 'angry', 'happy', 'sad', 'disgust', 'sad', 'calm', 'fear', 'calm', 'surprised', 'disgust', 'calm', 'fear', 'happy', 'fear', 'angry', 'neutral', 'sad', 'sad', 'disgust', 'surprised', 'surprised', 'calm', 'sad', 'sad', 'happy', 'disgust', 'calm', 'angry', 'happy', 'calm', 'disgust', 'calm', 'happy', 'calm', 'surprised', 'angry', 'disgust', 'neutral', 'sad', 'surprised', 'happy', 'surprised', 'fear', 'fear', 'surprised', 'angry', 'sad', 'angry', 'happy', 'angry', 'angry', 'disgust', 'happy', 'disgust', 'disgust', 'sad', 'neutral', 'fear', 'neutral', 'happy', 'disgust', 'fear', 'calm', 'angry', 'fear', 'surprised', 'fear', 'fear', 'sad', 'calm', 'sad', 'happy', 'sad', 'angry', 'calm', 'surprised', 'surprised', 'happy', 'disgust', 'fear', 'disgust', 'surprised', 'sad', 'neutral', 'calm', 'sad', 'surprised', 'surprised', 'disgust', 'fear', 'calm', 'surprised', 'angry', 'disgust', 'angry', 'angry', 'angry', 'fear', 'sad', 'happy', 'surprised', 'happy', 'sad', 'sad', 'sad', 'fear', 'calm', 'neutral', 'happy', 'angry', 'calm', 'disgust', 'neutral', 'calm', 'fear', 'fear', 'surprised', 'happy', 'fear', 'fear', 'angry', 'surprised', 'happy', 'neutral', 'sad', 'sad', 'disgust', 'disgust', 'disgust', 'angry', 'happy', 'angry', 'disgust', 'calm', 'happy', 'sad', 'calm', 'neutral', 'disgust', 'surprised', 'sad', 'calm', 'fear', 'happy', 'surprised', 'calm', 'happy', 'disgust', 'sad', 'angry', 'angry', 'calm', 'sad', 'disgust', 'disgust', 'disgust', 'happy', 'calm', 'disgust', 'surprised', 'sad', 'angry', 'neutral', 'neutral', 'fear', 'angry', 'disgust', 'angry', 'fear', 'surprised', 'surprised', 'fear', 'happy', 'calm', 'happy', 'happy', 'angry', 'angry', 'fear', 'happy', 'calm', 'happy', 'sad', 'fear', 'surprised', 'surprised', 'fear', 'disgust', 'calm', 'calm', 'sad', 'sad', 'sad', 'fear', 'surprised', 'calm', 'sad', 'neutral', 'surprised', 'neutral', 'fear', 'angry', 'surprised', 'happy', 'disgust', 'calm', 'calm', 'disgust', 'neutral', 'fear', 'surprised', 'calm', 'fear', 'sad', 'calm', 'sad', 'disgust', 'angry', 'surprised', 'surprised', 'happy', 'calm', 'angry', 'angry', 'surprised', 'fear', 'fear', 'angry', 'happy', 'angry', 'disgust', 'calm', 'surprised', 'angry', 'sad', 'happy', 'sad', 'surprised', 'disgust', 'disgust', 'sad', 'happy', 'fear', 'surprised', 'angry', 'surprised', 'calm', 'disgust', 'calm', 'disgust', 'angry', 'fear', 'neutral', 'happy', 'disgust', 'sad', 'neutral', 'calm', 'sad', 'fear', 'happy', 'happy', 'sad', 'fear', 'neutral', 'happy', 'calm', 'neutral', 'sad', 'calm', 'calm', 'fear', 'happy', 'happy', 'disgust', 'angry', 'surprised', 'calm', 'sad', 'sad', 'angry', 'angry', 'happy', 'angry', 'disgust', 'happy', 'fear', 'surprised', 'neutral', 'sad', 'surprised', 'happy', 'fear', 'surprised', 'disgust', 'disgust', 'happy', 'happy', 'neutral', 'calm', 'disgust', 'sad', 'angry', 'surprised', 'angry', 'surprised', 'fear', 'calm', 'fear', 'fear', 'disgust', 'sad', 'sad', 'surprised', 'fear', 'sad', 'calm', 'surprised', 'angry', 'calm', 'neutral', 'disgust', 'angry', 'disgust', 'happy', 'fear', 'fear', 'sad', 'sad', 'disgust', 'surprised', 'surprised', 'angry', 'calm', 'surprised', 'surprised', 'fear', 'calm', 'fear', 'fear', 'happy', 'calm', 'angry', 'happy', 'surprised', 'angry', 'neutral', 'calm', 'disgust', 'disgust', 'disgust', 'fear', 'surprised', 'angry', 'sad', 'calm', 'angry', 'angry', 'neutral', 'surprised', 'sad', 'sad', 'happy', 'happy', 'calm', 'neutral', 'calm', 'angry', 'fear', 'happy', 'calm', 'disgust', 'sad', 'happy', 'sad', 'neutral', 'fear', 'happy', 'happy', 'surprised', 'disgust', 'sad', 'disgust', 'disgust', 'angry', 'fear', 'angry', 'fear', 'angry', 'fear', 'sad', 'fear', 's ...

# %%
lb = LabelEncoder()
y_encoded = lb.fit_transform(emotions)  # angry→0, calm→1 etc.

df = pd.DataFrame({
    'label': y_encoded,
    'transcript': transcripts
})

df['feats'] = np.arange(len(X))

neutral_class = lb.transform(['neutral'])[0]
neutral_df = df[df['label'] == neutral_class]
other_df = df[df['label'] != neutral_class]

print(len(neutral_df)) # too many neutral samples --> need to be undersampled to 192

# undersampling neutral class
neutral_downsampled = neutral_df.sample(
    n=192,
    random_state=42
)
bal_df = pd.concat([
    neutral_downsampled,
    other_df
])

print(len(neutral_downsampled))

# shuffle
bal_df = bal_df.sample(
    frac=1,
    random_state=42
).reset_index(drop=True)

select = bal_df['feats'].values

X_bal = X[select]
y_bal = bal_df['label'].values
transcripts_bal = bal_df['transcript'].tolist()

# Train test split
X_train, X_test, y_train, y_test = train_test_split(
    X_bal, y_bal, stratify=y_bal, test_size=0.2, random_state=42
)

# label map
y_lb_encoded = dict(enumerate(lb.classes_))

# checking shapes of data
#print(f'X_train shape: {X_train.shape}')
#print(f'y_train shape: {y_train.shape}')
#print(f'X_test shape: {X_test.shape}')
#print(f'y_test shape: {y_test.shape}')
# Out:
# 1536
# 192

# %%
#x_traincnn = np.expand_dims(X_train_scaled, axis=2)
#x_testcnn = np.expand_dims(X_test_scaled, axis=2)

CNN_model = Sequential()
CNN_model.add(Conv2D(
    32,
    (3,3),
    activation='relu',
    padding='same',
    input_shape=(128,128,1)
))
CNN_model.add(MaxPooling2D((2,2)))
CNN_model.add(Dropout(0.1))
CNN_model.add(Conv2D(
    64,
    (3,3),
    activation='relu',
    padding='same'
))
CNN_model.add(MaxPooling2D((2,2)))
CNN_model.add(Dropout(0.3))
CNN_model.add(Conv2D(
    128,
    (3,3),
    activation='relu',
    padding='same'
))
CNN_model.add(MaxPooling2D((2,2)))
CNN_model.add(Dropout(0.3))
CNN_model.add(Conv2D(
    256,
    (3,3),
    activation='relu',
    padding='same'
))
CNN_model.add(MaxPooling2D((2,2)))
CNN_model.add(Dropout(0.4))
CNN_model.add(Flatten())
CNN_model.add(Dense(256, activation='relu'))
CNN_model.add(Dropout(0.4))
CNN_model.add(Dense(8, activation='softmax'))

CNN_model.compile(
    optimizer=Adam(learning_rate=0.0001),  # lowering lr
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

CNN_model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_22 (Conv2D)              │ (None, 128, 128, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_21 (MaxPooling2D) │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_29 (Dropout)            │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_23 (Conv2D)              │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_22 (MaxPooling2D) │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_30 (Dropout)            │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_24 (Conv2D)              │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_23 (MaxPooling2D) │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_31 (Dropout)            │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_25 (Conv2D)              │ (None, 16, 16, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_24 (MaxPooling2D) │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_32 (Dropout)            │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_5 (Flatten)             │ (None, 16384)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 256)            │     4,194,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_33 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 8)              │         2,056 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,584,456 (17.49 MB)
#  Trainable params: 4,584,456 (17.49 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train
results = CNN_model.fit(X_train, y_train,
    epochs=50,
    batch_size=32,
    verbose =1,
    validation_data=(X_test, y_test)
 )

# Evaluate
loss, accuracy = CNN_model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# Epoch 1/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 18s 215ms/step - accuracy: 0.1238 - loss: 2.1199 - val_accuracy: 0.1688 - val_loss: 2.0672
# Epoch 2/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.1840 - loss: 2.0257 - val_accuracy: 0.2792 - val_loss: 2.0346
# Epoch 3/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2060 - loss: 1.9813 - val_accuracy: 0.2662 - val_loss: 1.9968
# Epoch 4/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2663 - loss: 1.9158 - val_accuracy: 0.3247 - val_loss: 1.9588
# Epoch 5/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2622 - loss: 1.8868 - val_accuracy: 0.2532 - val_loss: 1.9624
# Epoch 6/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2818 - loss: 1.8471 - val_accuracy: 0.2760 - val_loss: 1.9342
# Epoch 7/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.3029 - loss: 1.8246 - val_accuracy: 0.3019 - val_loss: 1.8962
# Epoch 8/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.3005 - loss: 1.8217 - val_accuracy: 0.2922 - val_loss: 1.8939
# Epoch 9/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.3355 - loss: 1.7954 - val_accuracy: 0.3344 - val_loss: 1.8664
# Epoch 10/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.3054 - loss: 1.7784 - val_accuracy: 0.3474 - val_loss: 1.8701
# Epoch 11/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.3314 - loss: 1.7550 - val_accuracy: 0.3636 - val_loss: 1.8392
# Epoch 12/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.3534 - loss: 1.7432 - val_accuracy: 0.3409 - val_loss: 1.8401
# Epoch 13/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.3567 - loss: 1.7074 - val_accuracy: 0.3994 - val_loss: 1.7904
# Epoch 14/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.3754 - loss: 1.6960 - val_accuracy: 0.3896 - val_loss: 1.7587
# Epoch 15/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.3721 - loss: 1.6791 - val_accuracy: 0.4123 - val_loss: 1.7545
# Epoch 16/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.3901 - loss: 1.6542 - val_accuracy: 0.4091 - val_loss: 1.7201
# Epoch 17/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.3982 - loss: 1.6068 - val_accuracy: 0.4156 - val_loss: 1.7144
# Epoch 18/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.3982 - loss: 1.6101 - val_accuracy: 0.3571 - val_loss: 1.7483
# Epoch 19/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.4104 - loss: 1.5813 - val_accuracy: 0.3994 - val_loss: 1.6941
# Epoch 20/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4178 - loss: 1.5527 - val_accuracy: 0.4383 - val_loss: 1.6484
# Epoch 21/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.4129 - loss: 1.5448 - val_accuracy: 0.4123 - val_loss: 1.6453
# Epoch 22/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.4381 - loss: 1.5096 - val_accuracy: 0.3571 - val_loss: 1.6856
# Epoch 23/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.4471 - loss: 1.4877 - val_accuracy: 0.3799 - val_loss: 1.6405
# Epoch 24/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.4739 - loss: 1.4317 - val_accuracy: 0.4221 - val_loss: 1.5791
# Epoch 25/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.4536 - loss: 1.4524 - val_accuracy: 0.3799 - val_loss: 1.6115
# Epoch 26/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.4837 - loss: 1.3926 - val_accuracy: 0.4545 - val_loss: 1.5395
# Epoch 27/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.4723 - loss: 1.4201 - val_accuracy: 0.4058 - val_loss: 1.5881
# Epoch 28/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.4894 - loss: 1.3414 - val_accuracy: 0.4286 - val_loss: 1.5745
# Epoch 29/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.4805 - loss: 1.3637 - val_accuracy: 0.4156 - val_loss: 1.5427
# Epoch 30/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.4984 - loss: 1.3315 - val_accuracy: 0.4188 - val_loss: 1.5482
# Epoch 31/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.5220 - loss: 1.3270 - val_accuracy: 0.4870 - val_loss: 1.5030
# Epoch 32/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.5366 - loss: 1.2774 - val_accuracy: 0.4708 - val_loss: 1.4712
# Epoch 33/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.5350 - loss: 1.2651 - val_accuracy: 0.4870 - val_loss: 1.4687
# Epoch 34/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.5440 - loss: 1.2166 - val_accuracy: 0.4903 - val_loss: 1.4347
# Epoch 35/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5399 - loss: 1.2261 - val_accuracy: 0.4448 - val_loss: 1.4878
# Epoch 36/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5423 - loss: 1.2326 - val_accuracy: 0.4481 - val_loss: 1.4883
# Epoch 37/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.5627 - loss: 1.2024 - val_accuracy: 0.4286 - val_loss: 1.4937
# Epoch 38/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.5774 - loss: 1.1634 - val_accuracy: 0.4481 - val_loss: 1.4373
# Epoch 39/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.5822 - loss: 1.1272 - val_accuracy: 0.4513 - val_loss: 1.4396
# Epoch 40/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.5790 - loss: 1.1485 - val_accuracy: 0.5130 - val_loss: 1.3965
# Epoch 41/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.6083 - loss: 1.0835 - val_accuracy: 0.4935 - val_loss: 1.4045
# Epoch 42/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.5863 - loss: 1.1062 - val_accuracy: 0.4643 - val_loss: 1.4549
# Epoch 43/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.5839 - loss: 1.0932 - val_accuracy: 0.5162 - val_loss: 1.3729
# Epoch 44/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.6075 - loss: 1.0496 - val_accuracy: 0.5552 - val_loss: 1.3273
# Epoch 45/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.6132 - loss: 1.0331 - val_accuracy: 0.5195 - val_loss: 1.3745
# Epoch 46/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.6221 - loss: 1.0140 - val_accuracy: 0.5130 - val_loss: 1.3737
# Epoch 47/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.6336 - loss: 1.0083 - val_accuracy: 0.5260 - val_loss: 1.3418
# Epoch 48/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.6368 - loss: 0.9751 - val_accuracy: 0.5584 - val_loss: 1.3507
# Epoch 49/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.6384 - loss: 0.9628 - val_accuracy: 0.5390 - val_loss: 1.3454
# Epoch 50/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.6376 - loss: 0.9626 - val_accuracy: 0.5357 - val_loss: 1.2960
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5357 - loss: 1.2960
# Test Accuracy: 0.5357

# %%
# Visualising predictions versus actual labels

y_pred = np.argmax(CNN_model.predict(X_test), axis=1)
print(classification_report(y_test, y_pred, target_names=lb.classes_))

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(results.history['loss'], label='Train Loss')
plt.plot(results.history['val_loss'], label='Test Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(results.history['accuracy'], label='Train Accuracy')
plt.plot(results.history['val_accuracy'], label='Test Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# Confusion matrix heatmap - looking for diagonal dominance
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Reds',
            xticklabels=lb.classes_,
            yticklabels=lb.classes_)
plt.title('Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step
#               precision    recall  f1-score   support
#
#        angry       0.57      0.82      0.67        38
#         calm       0.71      0.97      0.82        38
#      disgust       0.50      0.51      0.51        39
#         fear       0.61      0.51      0.56        39
#        happy       0.43      0.46      0.44        39
#      neutral       0.16      0.13      0.14        38
#          sad       0.45      0.26      0.33        39
#    surprised       0.71      0.63      0.67        38
#
#     accuracy                           0.54       308
#    macro avg       0.52      0.54      0.52       308
# weighted avg       0.52      0.54      0.52       308

# %%
# Preprocessing for RNN

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

tokenized = tokenizer(
    transcripts_bal,
    padding='max_length',
    truncation=True,
    max_length=128,
    return_tensors="pt"
)

X_text = tokenized['input_ids'].numpy()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]

# %%
vocab_size = tokenizer.vocab_size
embed_dim = 128
hidden_dim = 256
num_classes = 8 # there are 8 emotions so we can write this directly
max_length = 128

# Embedding layer + LSTM
inputs  = Input(shape=(max_length,))
x = Embedding(input_dim=vocab_size, output_dim=embed_dim, mask_zero=True)(inputs)
x = Bidirectional(LSTM(hidden_dim, dropout=0.4))(x)
x = Dense(64, activation='relu')(x)
x = Dropout(0.4)(x)
outputs = Dense(num_classes, activation='softmax')(x)

text_model = Model(inputs, outputs)
text_model.summary()
# Out:
# Model: "functional_86"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_8       │ (None, 128)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_2         │ (None, 128, 128)  │  3,906,816 │ input_layer_8[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ not_equal_2         │ (None, 128)       │          0 │ input_layer_8[0]… │
# │ (NotEqual)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_2     │ (None, 512)       │    788,480 │ embedding_2[0][0… │
# │ (Bidirectional)     │                   │            │ not_equal_2[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_14 (Dense)    │ (None, 64)        │     32,832 │ bidirectional_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_28          │ (None, 64)        │          0 │ dense_14[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 8)         │        520 │ dropout_28[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 4,728,648 (18.04 MB)
#  Trainable params: 4,728,648 (18.04 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
X_text = tokenized['input_ids'].numpy()
y_text = y_bal

X_train_text, X_test_text, y_train_text, y_test_text = train_test_split(X_text, y_text, test_size=0.2, random_state=42)

# Train
text_model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

results2 = text_model.fit(
    X_train_text, y_train_text,
    epochs=25,
    batch_size=32,
    verbose = 1,
    validation_data=(X_test_text, y_test_text)
)

loss, accuracy = text_model.evaluate(X_test_text, y_test)
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# Epoch 1/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 8s 91ms/step - accuracy: 0.1433 - loss: 2.0795 - val_accuracy: 0.1364 - val_loss: 2.0794
# Epoch 2/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.1270 - loss: 2.0798 - val_accuracy: 0.1299 - val_loss: 2.0795
# Epoch 3/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.1075 - loss: 2.0800 - val_accuracy: 0.1299 - val_loss: 2.0798
# Epoch 4/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.1213 - loss: 2.0797 - val_accuracy: 0.1299 - val_loss: 2.0796
# Epoch 5/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.1270 - loss: 2.0795 - val_accuracy: 0.0877 - val_loss: 2.0801
# Epoch 6/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.1295 - loss: 2.0797 - val_accuracy: 0.1039 - val_loss: 2.0809
# Epoch 7/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.1327 - loss: 2.0799 - val_accuracy: 0.0942 - val_loss: 2.0802
# Epoch 8/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.1205 - loss: 2.0797 - val_accuracy: 0.1039 - val_loss: 2.0803
# Epoch 9/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.1099 - loss: 2.0799 - val_accuracy: 0.0942 - val_loss: 2.0805
# Epoch 10/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.1238 - loss: 2.0798 - val_accuracy: 0.1039 - val_loss: 2.0805
# Epoch 11/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.1393 - loss: 2.0795 - val_accuracy: 0.1039 - val_loss: 2.0809
# Epoch 12/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.1230 - loss: 2.0793 - val_accuracy: 0.1039 - val_loss: 2.0809
# Epoch 13/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.1270 - loss: 2.0796 - val_accuracy: 0.1039 - val_loss: 2.0810
# Epoch 14/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.1279 - loss: 2.0796 - val_accuracy: 0.1039 - val_loss: 2.0812
# Epoch 15/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.1295 - loss: 2.0794 - val_accuracy: 0.1039 - val_loss: 2.0817
# Epoch 16/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.1303 - loss: 2.0794 - val_accuracy: 0.1039 - val_loss: 2.0825
# Epoch 17/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.1384 - loss: 2.0786 - val_accuracy: 0.1039 - val_loss: 2.0826
# Epoch 18/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.1295 - loss: 2.0796 - val_accuracy: 0.1039 - val_loss: 2.0825
# Epoch 19/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.1270 - loss: 2.0791 - val_accuracy: 0.1039 - val_loss: 2.0824
# Epoch 20/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.1393 - loss: 2.0790 - val_accuracy: 0.1039 - val_loss: 2.0826
# Epoch 21/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.1352 - loss: 2.0790 - val_accuracy: 0.1039 - val_loss: 2.0830
# Epoch 22/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.1287 - loss: 2.0794 - val_accuracy: 0.1039 - val_loss: 2.0829
# Epoch 23/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.1376 - loss: 2.0790 - val_accuracy: 0.1039 - val_loss: 2.0834
# Epoch 24/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.1360 - loss: 2.0791 - val_accuracy: 0.1039 - val_loss: 2.0831
# Epoch 25/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.1189 - loss: 2.0797 - val_accuracy: 0.0909 - val_loss: 2.0829
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1071 - loss: 2.0798
# Test Accuracy: 0.1071

# %%
# Visualising

y_pred = np.argmax(text_model.predict(X_test_text), axis=1)
print(classification_report(y_test_text, y_pred, target_names=lb.classes_))

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(results2.history['loss'], label='Train Loss')
plt.plot(results2.history['val_loss'], label='Test Loss')
plt.title('Text Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(results2.history['accuracy'], label='Train Accuracy')
plt.plot(results2.history['val_accuracy'], label='Test Accuracy')
plt.title('Text Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

cm_text = confusion_matrix(y_test_text, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(cm_text, annot=True, fmt='d', cmap='Blues',
            xticklabels=lb.classes_,
            yticklabels=lb.classes_)
plt.title('Text Model Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step
#               precision    recall  f1-score   support
#
#        angry       0.00      0.00      0.00        38
#         calm       0.06      0.31      0.11        32
#      disgust       0.00      0.00      0.00        37
#         fear       0.00      0.00      0.00        38
#        happy       0.00      0.00      0.00        47
#      neutral       0.00      0.00      0.00        40
#          sad       0.00      0.00      0.00        39
#    surprised       0.12      0.49      0.19        37
#
#     accuracy                           0.09       308
#    macro avg       0.02      0.10      0.04       308
# weighted avg       0.02      0.09      0.03       308
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
#multimodal fusion

# Getting just probabilities
audio_probs = CNN_model.predict(X_test)
text_probs = text_model.predict(X_test_text)

# Using weighted avg
y_pred_fused = np.argmax(0.7*audio_probs + 0.3*text_probs, axis=1)

print(f"Accuracy:  {accuracy_score(y_test_text, y_pred_fused)*100:.4f}%")
print(classification_report(y_test_text, y_pred_fused, target_names=lb.classes_))


cm = confusion_matrix(y_test_text, y_pred_fused)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='PuRd',
            xticklabels=lb.classes_,
            yticklabels=lb.classes_)
plt.title('Multimodal Fusion Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()

# comparing all three models
audio_pred = np.argmax(audio_probs, axis=1)
text_pred = np.argmax(text_probs, axis=1)

print("Model Comparison:")
print(f"Audio CNN only: {accuracy_score(y_test, audio_pred)*100:.4f}%")
print(f"Text LSTM only: {accuracy_score(y_test, text_pred)*100:.4f}%")
print(f"Multimodal fusion: {accuracy_score(y_test, y_pred_fused)*100:.4f}%")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Accuracy:  11.6883%
#               precision    recall  f1-score   support
#
#        angry       0.09      0.11      0.10        38
#         calm       0.12      0.19      0.14        32
#      disgust       0.16      0.16      0.16        37
#         fear       0.05      0.03      0.03        38
#        happy       0.16      0.19      0.17        47
#      neutral       0.11      0.03      0.04        40
#          sad       0.07      0.08      0.07        39
#    surprised       0.15      0.16      0.16        37
#
#     accuracy                           0.12       308
#    macro avg       0.11      0.12      0.11       308
# weighted avg       0.11      0.12      0.11       308
# Model Comparison:
# Audio CNN only: 54.5455%
# Text LSTM only: 10.7143%
# Multimodal fusion: 54.5455%
